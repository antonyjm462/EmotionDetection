# %%
import pandas as pd
import numpy as np
import scipy
import sklearn
import nltk
import sys
sys.path.insert(1, '/content/drive/My Drive/Emotion-Detection')

# %%
df = pd.read_csv('/content/drive/My Drive/Emotion-Detection/jira_dataset_final.csv')

# %%
df.shape
# Out:
# (301279, 2)

# %%
df = df.dropna()
df.shape
# Out:
# (208044, 2)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df['Emotion'].unique()
# Out:
# array(['Fear', 'Happy', 'Bad', 'Sad', 'Surprise', 'Anger', 'Digust'],
#       dtype=object)

# %%
# !pip install emoji

# %%
import preprocessor as tp

# %%
df.shape
# Out:
# (208044, 2)

# %%
text = np.asarray(df['Text'].values)
string = []
for doc in text:
  string.append(str(doc))
text
# Out:
# array(['oh no adult school', 'bad depressing day ever r p',
#        'aww happy mothers day', ...,
#        "Easter is here again  are you worried about the lock down? We've got you covered! We will deliver your live chicken(s) in whatever quantity you desire  We are just a call away  #easter #again #worried #worry #lockdownlife #cover #covered #delivery💰 https://t co/A8uIga8Cah",
#        "Easter is here again  are you worried about the lock down? We've got you covered! We will deliver your live chicken(s) in whatever quantity you desire  We are just a call away  #easter #again #worried #worry #lockdownlife #cover #covered #delivery💰 #chickens #livechicken https://t co/dDIWKZ3oA3",
#        'This #website provides help for #youngpeople if they are #worried  #advice on how to #cope with #schools closing and what to do if they are feeling #unwell  https://t co/uS5sVhfmfE #StayAtHomeSaveLives #COVIDー19 https://t co/N9JBd8cOwM'],
#       dtype=object)

# %%
text = tp.normalize_corpus(string)

# %%
Dataset = list(zip(text,df['Emotion']))
np.random.shuffle(Dataset)
DF = pd.DataFrame(data = Dataset, columns=['Text', 'Emotion'])
DF.to_csv("/content/drive/My Drive/Emotion-Detection/dataset_final_preprocessed.csv", index=False, header=True)

# %%
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer(lower=True)
tokenizer.fit_on_texts(text)

with open('/content/drive/My Drive/Emotion-Detection/tokenizer.pickle','wb') as file:
    pickle.dump(tokenizer, file)
